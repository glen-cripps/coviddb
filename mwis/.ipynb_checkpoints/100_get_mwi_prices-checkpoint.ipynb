# %%
import datetime
num_days=7
start_sp = datetime.date.today() - datetime.timedelta(days=num_days)
end_sp = datetime.date.today()
from pandas_datareader import data as pdr


import arrow
today_dt = arrow.now().format('YYYYMMDD')
financial_indexes = pd.read_parquet("mwis." + today_dt + ".parquet")

# %%
# initialize a dataframe with the columns we want
all_financials_df = pd.DataFrame()
all_financials_df = pdr.get_data_yahoo('^GSPC', start_sp, end_sp)
all_financials_df['financial_index'] = '^GSPC'

# then delete the rows coz it will reload them in the loop below
all_financials_df = all_financials_df[0:0]

for fin_index in financial_indexes['yahoo_ticker']:
    try:
        financials_df = pdr.get_data_yahoo(fin_index, start_sp, end_sp)
        financials_df['financial_index'] = fin_index
    except:
        continue
    all_financials_df = all_financials_df.append(financials_df)

# %%
all_financials_df
# Out:
#                     High           Low          Open         Close  \
# Date
# 2020-03-23   2300.729980   2191.860107   2290.709961   2237.399902
# 2020-03-24   2449.709961   2344.439941   2344.439941   2447.330078
# 2020-03-25   2571.419922   2407.530029   2457.770020   2475.560059
# 2020-03-26   2637.010010   2500.719971   2501.290039   2630.070068
# 2020-03-27   2615.909912   2520.020020   2555.870117   2541.469971
# 2020-03-30   2626.199951   2545.280029   2558.979980   2624.959961
# 2020-03-23  19121.009766  18213.650391  19028.359375  18591.929688
# 2020-03-24  20737.699219  19649.250000  19722.189453  20704.910156
# 2020-03-25  22019.929688  20538.339844  21050.339844  21200.550781
# 2020-03-26  22595.060547  21427.099609  21468.380859  22552.169922
# 2020-03-27  22327.570312  21469.269531  21898.470703  21636.779297
# 2020-03-30  22297.189453  21522.080078  21678.220703  22280.050781
# 2020-03-23   6984.939941   6631.419922   6847.279785   6860.669922
# 2020-03-24   7418.370117   7169.859863   7196.149902   7417.859863
# 2020-03-25   7671.209961   7276.399902   7421.359863   7384.299805
# 2020-03-26   7809.830078   7462.209961   7462.209961   7797.540039
# 2020-03-27   7716.240234   7491.140137   7554.250000   7502.379883
# 2020-03-30   7762.605469   7539.965820   7583.459961   7760.467285
# 2020-03-23   9053.490234   8664.940430   9014.580078   8777.379883
# 2020-03-24   9672.009766   9276.639648   9276.639648   9658.320312
# 2020-03-25  10303.900391   9591.740234   9749.799805   9961.379883
# 2020-03-26  10556.900391  10060.480469  10060.480469  10536.280273
# 2020-03-27  10449.219727  10064.500000  10135.730469  10187.209961
# 2020-03-30  10375.015625  10131.600586  10238.130859  10371.646484
# 2020-03-23   1422.589966   1327.829956   1422.589966   1336.380005
# 2020-03-24   1466.530029   1410.609985   1430.489990   1464.969971
# 2020-03-25   1558.400024   1441.959961   1484.619995   1516.189941
# 2020-03-26   1615.609985   1516.189941   1516.189941   1550.349976
# 2020-03-27   1518.189941   1472.780029   1518.189941   1487.229980
# 2020-03-30   1500.857056   1437.243652   1475.838989   1480.431152
# ...                  ...           ...           ...           ...
# 2020-03-26  13592.299805  13138.299805  13154.099609  13371.200195
# 2020-03-24  25.160000  23.090000  24.139999  24.549999  300012410  24.549999
# 2020-03-25  25.070000  22.910000  24.830000  24.309999  290110034  24.309999
# 2020-03-26  24.219999  22.379999  24.170000  23.049999  270451784  23.049999
# 2020-03-27  23.139999  20.879999  23.080000  21.840000  250723427  21.840000
# 2020-03-29  20.930000  19.920000  20.930000  20.280001    3327282  20.280001
# 2020-03-30  20.860001  20.150000  20.490000  20.320000   66557210  20.320000
#
#            financial_index
# Date
# 2020-03-23            CL=F
# 2020-03-24            CL=F
# 2020-03-25            CL=F
# 2020-03-26            CL=F
# 2020-03-27            CL=F
# 2020-03-29            CL=F
# 2020-03-30            CL=F

# %%
import sys
import os


import pandas_datareader.data as web
import datetime
import pandas as pd

sleep_seconds = 0
num_days = 7
row_cap = 0

# %%
# for now let's just get NASDAQ working
exchanges = {
    "nyse":"http://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nyse&render=download",
    "amex":"http://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=amex&render=download",
    "nasdaq":"http://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download"
}

# %%
iter = 1
for exchange_key in exchanges:
    exchange_stocks = pd.DataFrame.from_csv(exchanges[exchange_key])
    iter = iter+1
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   app.launch_new_instance()

# %%
exchange_stocks
# Out:
#                                                       Name  LastSale  \
# Symbol
# DDD                                 3D Systems Corporation    7.4200
# MMM                                             3M Company  133.2400
# WBAI                                       500.com Limited    4.4100
# WUBA                                           58.com Inc.   47.3300
# EGHT                                               8x8 Inc   17.5300
# AHC                                  A.H. Belo Corporation    1.6900
# AOS                                  A.O Smith Corporation   36.8500
# ATEN                                    A10 Networks, Inc.    5.5700
# AIR                                              AAR Corp.   17.9900
# AAN                                     Aaron&#39;s,  Inc.   23.6500
# ABB                                                ABB Ltd   18.2200
# ABT                                    Abbott Laboratories   74.5600
# ABBV                                           AbbVie Inc.   72.6700
# ANF                            Abercrombie & Fitch Company    9.9100
# AGD                  Aberdeen Global Dynamic Dividend Fund    7.5200
# AWP                Aberdeen Global Premier Properties Fund    4.3800
# ACP                 Aberdeen Income Credit Strategies Fund    7.1500
# JEQ                      Aberdeen Japan Equity Fund, Inc.     6.2800
# AOD                   Aberdeen Total Dynamic Dividend Fund    6.7100
# ABM                            ABM Industries Incorporated   21.9900
# AKR                                    Acadia Realty Trust   13.7100
# ACEL                             Accel Entertainment, Inc.    7.5600
# ACEL.WS                          Accel Entertainment, Inc.       NaN
# ACN                                          Accenture plc  162.8800
# ACCO                               Acco Brands Corporation    5.1500
# ATV                              Acorn International, Inc.   10.6399
# AYI                                   Acuity Brands, Inc.    82.8200
# GOLF                               Acushnet Holdings Corp.   25.5200
# ADX                    Adams Diversified Equity Fund, Inc.   12.4000
# PEO                     Adams Natural Resources Fund, Inc.    8.4900
# ...                                                    ...       ...
# WK                                            Workiva Inc.   35.3100
# INT                        World Fuel Services Corporation   22.4400
# WWE                    World Wrestling Entertainment, Inc.   33.8000
# WOR                           Worthington Industries, Inc.   24.0700
# WPP                                                WPP plc   31.7600
# WPX                                       WPX Energy, Inc.    3.0800
# WYND                            Wyndham Destinations, Inc.   24.9200
# WH                          Wyndham Hotels & Resorts, Inc.   31.9700
# XYF                                            X Financial    0.9300
# XFLT     XAI Octagon Floating Rate & Alternative Income...    5.1900
# XHR                           Xenia Hotels & Resorts, Inc.   10.4100
# XRX                             Xerox Holdings Corporation   17.6600
# XIN                             Xinyuan Real Estate Co Ltd    2.1200
# XPO                                    XPO Logistics, Inc.   52.9200
# XYL                                             Xylem Inc.   65.5000
# AUY                                       Yamana Gold Inc.    2.9700
# YELP                                             Yelp Inc.   18.6400
# YETI                                   YETI Holdings, Inc.   20.9300
# YEXT                                            Yext, Inc.   10.9800
# YRD                                     Yiren Digital Ltd.    4.4600
# DAO                                           Youdao, Inc.   18.3600
# YPF                                   YPF Sociedad Anonima    3.8500
# YUMC                              Yum China Holdings, Inc.   42.5600
# YUM                                      Yum! Brands, Inc.   68.5300
# ZEN                                          Zendesk, Inc.   64.8500
# ZBH                           Zimmer Biomet Holdings, Inc.   94.9400
# ZTS                                            Zoetis Inc.  111.7700
# ZTO                              ZTO Express (Cayman) Inc.   25.5100
# ZUO                                            Zuora, Inc.    8.0900
# ZYME                                        Zymeworks Inc.   32.2900
#
#         MarketCap  IPOyear                 Sector  \
# Symbol
# DDD      $879.38M      NaN             Technology
# MMM       $76.65B      NaN            Health Care
# WBAI     $189.63M   2013.0      Consumer Services
# WUBA       $7.08B   2013.0             Technology
# EGHT        $1.8B      NaN             Technology
# AHC       $36.27M      NaN      Consumer Services
# AOS        $5.97B      NaN      Consumer Durables
# ATEN     $435.99M   2014.0             Technology
# AIR      $631.46M      NaN          Capital Goods
# AAN        $1.58B      NaN             Technology
# ABB       $38.87B      NaN      Consumer Durables
# ABT      $131.48B      NaN            Health Care
# ABBV     $107.31B   2012.0            Health Care
# ANF      $622.21M      NaN      Consumer Services
# AGD       $94.37M   2006.0                    NaN
# AWP      $374.09M   2007.0                    NaN
# ACP      $124.64M   2011.0                    NaN
# JEQ       $84.19M   1992.0                    NaN
# AOD      $707.44M   2007.0                    NaN
# ABM        $1.47B      NaN                Finance
# AKR        $1.19B      NaN      Consumer Services
# ACEL     $591.45M   2017.0      Consumer Services
# ACEL.WS       NaN      NaN                    NaN
# ACN      $103.85B   2001.0          Miscellaneous
# ACCO     $497.78M      NaN      Consumer Durables
# ATV       $27.46M   2007.0      Consumer Services
# AYI        $3.28B      NaN      Consumer Durables
# GOLF        $1.9B   2016.0  Consumer Non-Durables
# ADX        $1.35B      NaN                    NaN
# PEO       $253.5M      NaN                    NaN
# ...           ...      ...                    ...
# WK         $1.66B   2014.0             Technology
# INT        $1.47B      NaN                 Energy
# WWE        $2.61B      NaN      Consumer Services
# WOR        $1.31B      NaN          Capital Goods
# WPP        $7.78B      NaN             Technology
# WPX        $1.75B   2011.0                 Energy
# WYND       $2.18B      NaN      Consumer Services
# WH            $3B   2018.0      Consumer Services
# XYF       $148.3M   2018.0                Finance
# XFLT      $48.32M   2017.0                    NaN
# XHR        $1.17B   2015.0      Consumer Services
# XRX        $3.76B      NaN             Technology
# XIN      $126.99M   2007.0       Basic Industries
# XPO        $4.89B      NaN      Consumer Services
# XYL        $11.8B   2011.0          Capital Goods
# AUY        $2.83B      NaN       Basic Industries
# YELP       $1.34B   2012.0      Consumer Services
# YETI       $1.82B   2018.0  Consumer Non-Durables
# YEXT       $1.27B   2017.0             Technology
# YRD      $420.34M   2015.0                Finance
# DAO        $2.05B   2019.0      Consumer Services
# YPF        $1.51B   1993.0                 Energy
# YUMC      $15.99B   2016.0      Consumer Services
# YUM       $20.62B      NaN      Consumer Services
# ZEN        $7.35B   2014.0             Technology
# ZBH       $19.62B      NaN            Health Care
# ZTS       $53.08B   2013.0            Health Care
# ZTO       $19.95B   2016.0         Transportation
# ZUO      $915.79M   2018.0             Technology
# ZYME       $1.27B   2017.0            Health Care
#
#                                                 industry  \
# Symbol
# DDD              Computer Software: Prepackaged Software
# MMM                           Medical/Dental Instruments
# WBAI               Services-Misc. Amusement & Recreation
# WUBA     Computer Software: Programming, Data Processing
# EGHT                                        EDP Services
# AHC                                 Newspapers/Magazines
# AOS                      Consumer Electronics/Appliances
# ATEN                   Computer Communications Equipment
# AIR                                            Aerospace
# AAN                      Diversified Commercial Services
# ABB                                  Electrical Products
# ABT                                Major Pharmaceuticals
# ABBV                               Major Pharmaceuticals
# ANF                       Clothing/Shoe/Accessory Stores
# AGD                                                  NaN
# AWP                                                  NaN
# ACP                                                  NaN
# JEQ                                                  NaN
# AOD                                                  NaN
# ABM                      Diversified Commercial Services
# AKR                        Real Estate Investment Trusts
# ACEL               Services-Misc. Amusement & Recreation
# ACEL.WS                                              NaN
# ACN                                    Business Services
# ACCO                                          Publishing
# ATV                               Other Specialty Stores
# AYI                                    Building Products
# GOLF                          Recreational Products/Toys
# ADX                                                  NaN
# PEO                                                  NaN
# ...                                                  ...
# WK               Computer Software: Prepackaged Software
# INT                               Oil Refining/Marketing
# WWE                                 Movies/Entertainment
# WOR                                       Steel/Iron Ore
# WPP                                          Advertising
# WPX                                 Oil & Gas Production
# WYND                                      Hotels/Resorts
# WH                                        Hotels/Resorts
# XYF                           Finance: Consumer Services
# XFLT                                                 NaN
# XHR                                       Hotels/Resorts
# XRX                        Computer peripheral equipment
# XIN                                         Homebuilding
# XPO                              Transportation Services
# XYL                                       Fluid Controls
# AUY                                      Precious Metals
# YELP                             Other Consumer Services
# YETI                          Recreational Products/Toys
# YEXT                                        EDP Services
# YRD                           Finance: Consumer Services
# DAO                              Other Consumer Services
# YPF                             Integrated oil Companies
# YUMC                                         Restaurants
# YUM                                          Restaurants
# ZEN                                         EDP Services
# ZBH                               Industrial Specialties
# ZTS                                Major Pharmaceuticals
# ZTO                    Trucking Freight/Courier Services
# ZUO              Computer Software: Prepackaged Software
# ZYME                               Major Pharmaceuticals
#
#                                  Summary Quote  Unnamed: 8
# Symbol
# DDD          https://old.nasdaq.com/symbol/ddd         NaN
# MMM          https://old.nasdaq.com/symbol/mmm         NaN
# WBAI        https://old.nasdaq.com/symbol/wbai         NaN
# WUBA        https://old.nasdaq.com/symbol/wuba         NaN
# EGHT        https://old.nasdaq.com/symbol/eght         NaN
# AHC          https://old.nasdaq.com/symbol/ahc         NaN
# AOS          https://old.nasdaq.com/symbol/aos         NaN
# ATEN        https://old.nasdaq.com/symbol/aten         NaN
# AIR          https://old.nasdaq.com/symbol/air         NaN
# AAN          https://old.nasdaq.com/symbol/aan         NaN
# ABB          https://old.nasdaq.com/symbol/abb         NaN
# ABT          https://old.nasdaq.com/symbol/abt         NaN
# ABBV        https://old.nasdaq.com/symbol/abbv         NaN
# ANF          https://old.nasdaq.com/symbol/anf         NaN
# AGD          https://old.nasdaq.com/symbol/agd         NaN
# AWP          https://old.nasdaq.com/symbol/awp         NaN
# ACP          https://old.nasdaq.com/symbol/acp         NaN
# JEQ          https://old.nasdaq.com/symbol/jeq         NaN
# AOD          https://old.nasdaq.com/symbol/aod         NaN
# ABM          https://old.nasdaq.com/symbol/abm         NaN
# AKR          https://old.nasdaq.com/symbol/akr         NaN
# ACEL        https://old.nasdaq.com/symbol/acel         NaN
# ACEL.WS  https://old.nasdaq.com/symbol/acel.ws         NaN
# ACN          https://old.nasdaq.com/symbol/acn         NaN
# ACCO        https://old.nasdaq.com/symbol/acco         NaN
# ATV          https://old.nasdaq.com/symbol/atv         NaN
# AYI          https://old.nasdaq.com/symbol/ayi         NaN
# GOLF        https://old.nasdaq.com/symbol/golf         NaN
# ADX          https://old.nasdaq.com/symbol/adx         NaN
# PEO          https://old.nasdaq.com/symbol/peo         NaN
# ...                                        ...         ...
# WK            https://old.nasdaq.com/symbol/wk         NaN
# INT          https://old.nasdaq.com/symbol/int         NaN
# WWE          https://old.nasdaq.com/symbol/wwe         NaN
# WOR          https://old.nasdaq.com/symbol/wor         NaN
# WPP          https://old.nasdaq.com/symbol/wpp         NaN
# WPX          https://old.nasdaq.com/symbol/wpx         NaN
# WYND        https://old.nasdaq.com/symbol/wynd         NaN
# WH            https://old.nasdaq.com/symbol/wh         NaN
# XYF          https://old.nasdaq.com/symbol/xyf         NaN
# XFLT        https://old.nasdaq.com/symbol/xflt         NaN
# XHR          https://old.nasdaq.com/symbol/xhr         NaN
# XRX          https://old.nasdaq.com/symbol/xrx         NaN
# XIN          https://old.nasdaq.com/symbol/xin         NaN
# XPO          https://old.nasdaq.com/symbol/xpo         NaN
# XYL          https://old.nasdaq.com/symbol/xyl         NaN
# AUY          https://old.nasdaq.com/symbol/auy         NaN
# YELP        https://old.nasdaq.com/symbol/yelp         NaN
# YETI        https://old.nasdaq.com/symbol/yeti         NaN
# YEXT        https://old.nasdaq.com/symbol/yext         NaN
# YRD          https://old.nasdaq.com/symbol/yrd         NaN
# DAO          https://old.nasdaq.com/symbol/dao         NaN
# YPF          https://old.nasdaq.com/symbol/ypf         NaN
# YUMC        https://old.nasdaq.com/symbol/yumc         NaN
# YUM          https://old.nasdaq.com/symbol/yum         NaN
# ZEN          https://old.nasdaq.com/symbol/zen         NaN
# ZBH          https://old.nasdaq.com/symbol/zbh         NaN
# ZTS          https://old.nasdaq.com/symbol/zts         NaN
# ZTO          https://old.nasdaq.com/symbol/zto         NaN
# ZUO          https://old.nasdaq.com/symbol/zuo         NaN
# ZYME        https://old.nasdaq.com/symbol/zyme         NaN
#
# [3103 rows x 8 columns]

# %%
#stocks = df.index.tolist()
print("brealk")
import arrow
import time
#
# # We will look at stock prices over the past year, starting at January 1, 2016
start = datetime.date.today() - datetime.timedelta(days=num_days)
end = datetime.date.today()

today_dt = arrow.now().format('YYYYMMDD')

if row_cap > 0:
    all_exchange_stocks = all_exchange_stocks.head(row_cap)

#all_exchange_stocks = all_exchange_stocks.head(25)
iter = 1
for index, row in all_exchange_stocks.iterrows():
    if iter == 1:
        all_stocks_header = all_exchange_stocks[all_exchange_stocks.index==0]
        stock_hist = web.DataReader(row.StockTicker, "yahoo", start, end)
        time.sleep(sleep_seconds)
        stock_hist.reset_index(inplace=True)
        stock_hist["Exchange"] = row.Exchange
        stock_hist["StockTicker"] = row.StockTicker
        all_stocks_hist = stock_hist.copy()
    else:
        try:
            print("processing " + row.Exchange + "-" + row.StockTicker)
            stock_hist = web.DataReader(row.StockTicker, "yahoo", start, end, retry_count=2)
            time.sleep(sleep_seconds)
            stock_hist.reset_index(inplace=True)
            all_stocks_header = all_stocks_header.append(row, ignore_index=True)
#            print(stock_hist.head())
            stock_hist["Exchange"] = row.Exchange
            stock_hist["StockTicker"] = row.StockTicker
            all_stocks_hist = all_stocks_hist.append(stock_hist,ignore_index=True)
        except:
            print("wtf unable to download " + row.Exchange + "-" + row.StockTicker)
            pass
    iter = iter + 1
    #    print(stockdata.head())


all_stocks_hist.columns = all_stocks_hist.columns.str.replace(' ', '_')
all_stocks_hist.columns = all_stocks_hist.columns.astype(str)

all_stocks_header.to_parquet('/home/user/Glens_work/all_stocks_header.' + today_dt + '.parquet',compression='gzip')
all_stocks_hist.to_parquet('/home/user/Glens_work/all_stocks_hist.' + today_dt + '.parquet',compression='gzip')




print(all_stocks_header.head())
print(all_stocks_hist.head())
print("End!")
